# %%
! pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mirajdeepbhandari/fuseip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mirajdeepbhandari/fuseip
# License(s): unknown
# ...
# 100% 4.68G/4.69G [00:36<00:00, 149MB/s]
# 100% 4.69G/4.69G [00:37<00:00, 136MB/s]

# %%
# !unzip /content/fuseip.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fuse_yolodata/valid/labels/shuffled_val01762.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01763.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01764.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01765.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01766.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01767.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01768.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01769.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01770.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01771.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01772.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01773.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01774.txt
#   inflating: fuse_yolodata/valid/labels/shuffled_val01775.txt
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 38810, done.
# remote: Counting objects: 100% (1211/1211), done.
# remote: Compressing objects: 100% (503/503), done.
# remote: Total 38810 (delta 856), reused 975 (delta 708), pack-reused 37599 (from 1)
# Receiving objects: 100% (38810/38810), 30.21 MiB | 19.75 MiB/s, done.
# Resolving deltas: 100% (28450/28450), done.
# Updating files: 100% (651/651), done.

# %%
# %cd ultralytics
# Out:
# /content/drive/MyDrive/ultralytics

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.2.83-0.editable-py3-none-any.whl size=23153 sha256=b26c689159b9cf17e7851283d4676bae194ebd6169eeaec59b839159ab1c4671
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ylk8hd1n/wheels/00/82/9f/981d6bf9ff6cebb0663fafe1c04d486874edc8cbd7d45b4853
# Successfully built ultralytics
# ...

# %%
# import os
# import urllib.request

# # Create a directory for the weights in the current working directory
# weights_dir = os.path.join(os.getcwd(), "weights")
# os.makedirs(weights_dir, exist_ok=True)

# # URLs of the weight files
# urls = [
#     "https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt",
# ]

# # Download each file
# for url in urls:
#     file_name = os.path.join(weights_dir, os.path.basename(url))
#     urllib.request.urlretrieve(url, file_name)
#     print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/drive/MyDrive/ultralytics/weights/yolov8s.pt

# %%
# lasr weight - /content/drive/MyDrive/last.pt

# %%
# !yolo task=detect mode=train epochs=100 batch=32 plots=True model=/content/drive/MyDrive/Genesis/last.pt  data=/content/fuse_yolodata/data.yaml
# Out:
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
